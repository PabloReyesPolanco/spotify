# %%
import pandas as pd
from cosas_spotipy import *

# %% [markdown]
# # 1. Importar datos y filtrar

# %%
df = pd.read_csv("Spotify Weekly.csv")
df = df.drop(["url","time_signature","key","mode"], axis = 1)
df["duration_s"] = df["duration_ms"]/1000
df["duration_m"] = df["duration_ms"]/1000/60

# %% [markdown]
# ## 1.1. Filtrar previo al 2016

# %%
print(f"filas iniciales: {len(df)}")
# eliminamos el 2016
df = df[df.year > 2016]
print(f"filas primer filtro: {len(df)}")
df.head(3)
# Out:
# filas iniciales: 52200
# filas primer filtro: 52000
#      position  year       start         end  \
# 200         1  2017  2016-12-30  2017-01-06
# 201         2  2017  2016-12-30  2017-01-06
# 202         3  2017  2016-12-30  2017-01-06
#
#                                   track_name            artist   streams  \
# 200                                  Starboy        The Weeknd  25734078
# 201                                   Closer  The Chainsmokers  23519705
# 202  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit  21216399
#
#      danceability  energy  loudness  speechiness  acousticness  \
# 200         0.681   0.594    -7.028       0.2820         0.165
# 201         0.748   0.524    -5.599       0.0338         0.414
# 202         0.720   0.763    -4.068       0.0523         0.406
#
#      instrumentalness  liveness  valence    tempo  duration_ms  duration_s  \
# 200          0.000003     0.134    0.535  186.054       230453     230.453
# 201          0.000000     0.111    0.661   95.010       244960     244.960
# 202          0.000000     0.180    0.742  101.965       251088     251.088
#
#      duration_m
# 200    3.840883
# 201    4.082667
# 202    4.184800

# %% [markdown]
# ## 1.2. Eliminar filas nulas

# %%
df.isnull().sum()
# Out:
# position            0
# year                0
# start               0
# end                 0
# track_name          7
# artist              7
# streams             0
# danceability        0
# energy              0
# loudness            0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# duration_s          0
# duration_m          0
# dtype: int64

# %%
# Se votan los nulos
df = df.dropna(axis = 0)
print(f"filas segundo filtro: {len(df)}")
# Out:
# filas segundo filtro: 51993

# %% [markdown]
# ## 1.3. Ordenar datos

# %%
df = df.sort_values(["start","position"])
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # 2. Estadísticas Resumen

# %%
df[['danceability','energy','loudness', 'speechiness','acousticness',
    'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']].mean().to_frame()
# Out:
#                               0
# danceability           0.694645
# energy                 0.631853
# loudness              -6.128581
# speechiness            0.113158
# acousticness           0.237283
# instrumentalness       0.007872
# liveness               0.167300
# valence                0.504907
# tempo                120.058088
# duration_ms       206324.583155

# %%
df[['danceability','energy','loudness', 'speechiness','acousticness',
    'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']].std().to_frame()
# Out:
#                              0
# danceability          0.135100
# energy                0.161958
# loudness              2.391065
# speechiness           0.100587
# acousticness          0.239881
# instrumentalness      0.053434
# liveness              0.124589
# valence               0.222525
# tempo                29.071469
# duration_ms       41785.995506

# %% [markdown]
# # Reproducciones anuales

# %%
streams_total = df[["year", "streams"]]
streams_total = streams_total.groupby("year", as_index = False).sum().sort_values("year")
streams_total.set_index("year", inplace = True)
streams_total
# Out:
#            streams
# year
# 2017   76506178881
# 2018   84465788692
# 2019   88242484766
# 2020   94796398526
# 2021  100131968788

# %%
streams_total.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # Artistas seguún streams

# %%
artists_streams = df[["artist","year","streams"]]
artists_streams = artists_streams.groupby(["year", "artist"], as_index = False).sum().sort_values("year")
artists_streams["position_year"] = artists_streams.groupby(["year"])["streams"].rank(ascending = False)
artists_streams.set_index("year", inplace = True)
artists_streams[artists_streams.position_year == 1]
# Out:
#               artist     streams  position_year
# year
# 2017      Ed Sheeran  4626030792            1.0
# 2018     Post Malone  4523248176            1.0
# 2019     Post Malone  4964093501            1.0
# 2020       Bad Bunny  3319513438            1.0
# 2021  Olivia Rodrigo  5064291089            1.0

# %%
artist_sum = df[["artist","track_name","streams"]]
artist_sum = artist_sum.groupby(["track_name", "artist"], as_index = False).sum().sort_values("streams", ascending = False)
artist_sum["position"] = artist_sum.groupby(["track_name", "artist"])["streams"].rank(ascending = False)
artist_sum.query( "artist == 'Post Malone'")
# Out:
#                                              track_name       artist  \
# 3312      Sunflower - Spider-Man: Into the Spider-Verse  Post Malone
# 697                                             Circles  Post Malone
# 441                                          Better Now  Post Malone
# 4135                         rockstar (feat. 21 Savage)  Post Malone
# 741                                     Congratulations  Post Malone
# 4134                                           rockstar  Post Malone
# 3895                                               Wow.  Post Malone
# 2732                       Psycho (feat. Ty Dolla $ign)  Post Malone
# 1599                                       I Fall Apart  Post Malone
# 1364                        Goodbyes (Feat. Young Thug)  Post Malone
# 628                                         Candy Paint  Post Malone
# 3840                                      White Iverson  Post Malone
# 3377  Take What You Want (feat. Ozzy Osbourne & Trav...  Post Malone
# 1330                                            Go Flex  Post Malone
# 2986                                       Saint-Tropez  Post Malone
# 364                     Ball For Me (feat. Nicki Minaj)  Post Malone
# 2627                                           Paranoid  Post Malone
# 1523                               Hollywood's Bleeding  Post Malone
# 1056                             Enemies (feat. DaBaby)  Post Malone
# 2536                    One Right Now (with The Weeknd)  Post Malone
# 2284                                        Motley Crew  Post Malone
# 3230                    Spoil My Night (feat. Swae Lee)  Post Malone
# 3250                                               Stay  Post Malone
# 2868                                         Rich & Sad  Post Malone
# 891                  Die For Me (feat. Future & Halsey)  Post Malone
# 2569                                           Over Now  Post Malone
# 2521           On The Road (feat. Meek Mill & Lil Baby)  Post Malone
# 85                                          92 Explorer  Post Malone
# 3978                                   Zack And Codeine  Post Malone
# 2990                   Same Bitches (feat. G-Eazy & YG)  Post Malone
# 3384                                       Takin' Shots  Post Malone
# 98                                 A Thousand Bad Times  Post Malone
# 2554                                          Otherside  Post Malone
# 197                                            Allergic  Post Malone
# 1650                                       I'm Gonna Be  Post Malone
# 3238                     Staring At The Sun (feat. SZA)  Post Malone
# 473                                      Blame It On Me  Post Malone
# 1365                        Goodbyes (feat. Young Thug)  Post Malone
# 3295                                       Sugar Wraith  Post Malone
# 3896                                       Wow. - Remix  Post Malone
# 2315                                             Myself  Post Malone
# 1612                                             I Know  Post Malone
# 1721                                           Internet  Post Malone
# 1782                              Jonestown (Interlude)  Post Malone
# 2542        Only Wanna Be With You - Pokémon 25 Version  Post Malone
#
#          streams  position
# 3312  2067398862       1.0
# 697   1599146210       1.0
# 441   1220325977       1.0
# 4135  1112059483       1.0
# 741    982927532       1.0
# 4134   954452582       1.0
# 3895   932133100       1.0
# 2732   905310515       1.0
# 1599   745318733       1.0
# 1364   654675084       1.0
# 628    370420835       1.0
# 3840   221311688       1.0
# 3377   205328388       1.0
# 1330   199348913       1.0
# 2986   161171998       1.0
# 364    154428197       1.0
# 2627   131467348       1.0
# 1523   129787906       1.0
# 1056   127662405       1.0
# 2536   120345118       1.0
# 2284   119099898       1.0
# 3230   100446929       1.0
# 3250    98985894       1.0
# 2868    85733606       1.0
# 891     77922918       1.0
# 2569    70679346       1.0
# 2521    65951429       1.0
# 85      61811436       1.0
# 3978    60589696       1.0
# 2990    58778680       1.0
# 3384    52463959       1.0
# 98      48490290       1.0
# 2554    38222422       1.0
# 197     36394259       1.0
# 1650    35715621       1.0
# 3238    35310154       1.0
# 473     34954788       1.0
# 1365    34540826       1.0
# 3295    31446293       1.0
# 3896    30659321       1.0
# 2315    24056656       1.0
# 1612    18080220       1.0
# 1721    17518360       1.0
# 1782    16196878       1.0
# 2542     7464020       1.0

# %% [markdown]
# # Apariciones en el top en los últimos 5 años por artista

# %%
top_aparitions = artist_sum[["artist","track_name"]]
top_aparitions = top_aparitions.groupby(["artist"], as_index = False).count()
top_aparitions["position"] = top_aparitions["track_name"].rank(ascending = False)
top_aparitions.sort_values("position", inplace= True)
top_aparitions
# Out:
#              artist  track_name  position
# 827    Taylor Swift         112       1.0
# 237           Drake         101       2.0
# 80              BTS          64       3.0
# 57    Ariana Grande          57       4.0
# 250      Ed Sheeran          56       5.0
# ..              ...         ...       ...
# 397     Jon Bellion           1     702.5
# 400  Jonas Esticado           1     702.5
# 403  José Feliciano           1     702.5
# 405  Jowell & Randy           1     702.5
# 955          zzoilo           1     702.5
#
# [956 rows x 3 columns]

# %% [markdown]
# # Canciones artista por semana

# %%
artist_week = df[["year","start","artist", "streams"]]
artist_week = artist_week.groupby(["year","start", "artist"], as_index = False).count().sort_values("streams", ascending = False)
artist_week.columns = ["year","start","artist", "aparitions"]
artist_week
# Out:
#        year       start          artist  aparitions
# 30950  2021  2021-11-12    Taylor Swift          34
# 29525  2021  2021-08-27      Kanye West          27
# 1512   2017  2017-03-17           Drake          27
# 9805   2018  2018-07-06           Drake          26
# 9688   2018  2018-06-29           Drake          26
# ...     ...         ...             ...         ...
# 12607  2018  2018-12-21  Brett Eldredge           1
# 12606  2018  2018-12-21      Brenda Lee           1
# 12605  2018  2018-12-21     Bobby Helms           1
# 12604  2018  2018-12-21      BlocBoy JB           1
# 31752  2021  2021-12-24          zzoilo           1
#
# [31753 rows x 4 columns]

# %%
artist_year = artist_week[["year","artist","aparitions"]]
artist_year = artist_year.groupby(["year","artist"], as_index = False).count().sort_values("aparitions", ascending = False)
artist_year.reset_index(inplace=True)
artist_year
# Out:
#       index  year           artist  aparitions
# 0      1667  2021         J Balvin          53
# 1      1662  2021  Imagine Dragons          53
# 2      1692  2021    Justin Bieber          53
# 3      1608  2021            Drake          53
# 4      1895  2021           Tiësto          53
# ...     ...   ...              ...         ...
# 1934    290  2017         Stargate           1
# 1935    636  2018          Rvssian           1
# 1936    635  2018             Russ           1
# 1937    629  2018   Ray Parker Jr.           1
# 1938      0  2017           *NSYNC           1
#
# [1939 rows x 4 columns]

# %% [markdown]
# # Revision agrupando por año

# %%
top_yearly = df[["track_name","year","artist", "streams"]]
top_yearly = top_yearly.groupby(["track_name","year","artist"], as_index = False).sum().sort_values("streams", ascending = False)

top_yearly["position_year"] = top_yearly.groupby(["year"])["streams"].rank(ascending = False)
top_yearly.reset_index(inplace = True)

pl = top_yearly.year.value_counts().to_frame().sort_index()
pl.reset_index(inplace = True)
pl.columns = ["year", "songs"]
pl = pl.set_index("year")
pl
# de aqui se puede concluir cual es la cantidad de canciones distintas que se han metido al top
# Out:
#       songs
# year
# 2017    889
# 2018   1138
# 2019   1056
# 2020   1152
# 2021   1043

# %%
pl.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
aux = pl
mean = aux.songs.mean()
std = aux.songs.std()

aux["lo"] = aux["songs"] - 1.96*std/5**0.5
aux["hi"] = aux["songs"] + 1.96*std/5**0.5

aux[["songs","lo","hi"]].plot(title = "canciones", grid = True, figsize = (20,6))
# Out:
# <AxesSubplot:title={'center':'canciones'}, xlabel='year'>

# %%
p2 = top_yearly
p2[p2.position_year == 1].sort_values("year")
# Out:
#    index                 track_name  year         artist     streams  \
# 1   3876               Shape of You  2017     Ed Sheeran  1514648943
# 6   1641                 God's Plan  2018          Drake  1138561345
# 8   3864                   Señorita  2019   Shawn Mendes  1081998529
# 0    596            Blinding Lights  2020     The Weeknd  1660934276
# 3   3704  STAY (with Justin Bieber)  2021  The Kid LAROI  1209831797
#
#    position_year
# 1            1.0
# 6            1.0
# 8            1.0
# 0            1.0
# 3            1.0

# %% [markdown]
# ## Revisar grupo global

# %%
top_global = df[["track_name","artist", "streams"]]
top_global = top_global.groupby(["track_name","artist"], as_index = False).sum().sort_values("streams", ascending = False)

top_global["position_global"] = top_global["streams" ].rank(ascending = False)
top_global.reset_index(inplace = True)
top_global.head(10)
# Out:
#    index                                     track_name           artist  \
# 0   3081                                   Shape of You       Ed Sheeran
# 1    484                                Blinding Lights       The Weeknd
# 2    827                                   Dance Monkey      Tones And I
# 3   3211                              Someone You Loved    Lewis Capaldi
# 4   3312  Sunflower - Spider-Man: Into the Spider-Verse      Post Malone
# 5   3074                                       Señorita     Shawn Mendes
# 6    415                                       Believer  Imagine Dragons
# 7   3993                                        bad guy    Billie Eilish
# 8   2653                                        Perfect       Ed Sheeran
# 9   2079                                   Lucid Dreams       Juice WRLD
#
#       streams  position_global
# 0  2970775515              1.0
# 1  2666668171              2.0
# 2  2411875476              3.0
# 3  2143170112              4.0
# 4  2067398862              5.0
# 5  1968618562              6.0
# 6  1912530286              7.0
# 7  1900912195              8.0
# 8  1892115454              9.0
# 9  1745314626             10.0

# %% [markdown]
# ## moda anual

# %%
moda_anual  = df[["track_name", "artist","year"]]
moda_anual = moda_anual.groupby(["track_name", "artist","year"], as_index= False).size()
moda_anual.columns = ["track_name", "artist","year","counts"]
moda_anual  = moda_anual.sort_values("counts", ascending = False)
aa = moda_anual[moda_anual.year == 2021 ]
bb = moda_anual[moda_anual.year ==2020 ]
cc = moda_anual[moda_anual.year == 2019]
dd = moda_anual[moda_anual.year == 2018]
ee = moda_anual[moda_anual.year == 2017]

# %%
print(aa, bb)
# Out:
#                            track_name              artist  year  counts
# 2452        Levitating (feat. DaBaby)            Dua Lipa  2021      53
# 872                           Circles         Post Malone  2021      53
# 5175             lovely (with Khalid)       Billie Eilish  2021      53
# 1824                          Heather          Conan Gray  2021      53
# 1821                       Heat Waves       Glass Animals  2021      53
# ...                               ...                 ...   ...     ...
# 1482                      First Times          Ed Sheeran  2021       1
# 3646              Ruff Ryders' Anthem                 DMX  2021       1
# 3683  SIR BAUDELAIRE (feat. DJ Drama)  Tyler, The Creator  2021       1
# 3677                             SHUM                Go_A  2021       1
# 3672                        SCIENTIST               TWICE  2021       1
#
# [1043 rows x 4 columns]                           track_name         artist  year  counts
# 1706             HIGHEST IN THE ROOM   Travis Scott  2020      52
# 154                        Adore You   Harry Styles  2020      52
# 503                    Before You Go  Lewis Capaldi  2020      52
# 5124                      goosebumps   Travis Scott  2020      52
# 3600                         Robbery     Juice WRLD  2020      52
# ...                              ...            ...   ...     ...
# 3686                          SKYBOX          Gunna  2020       1
# 3685                            SKRR          KALIM  2020       1
# 3678                    SI ELLA SALE      Bad Bunny  2020       1
# 3666  Running Over (feat. Lil Dicky)  Justin Bieber  2020       1
# 1427                        Farewell         Eminem  2020       1
#
# [1152 rows x 4 columns]

# %%
print(cc, dd)
# Out:
#                                 track_name         artist  year  counts
# 3878                          Shape of You     Ed Sheeran  2019      51
# 3872                               Shallow      Lady Gaga  2019      51
# 5254                 when the party's over  Billie Eilish  2019      51
# 4872                            Without Me         Halsey  2019      51
# 5223            rockstar (feat. 21 Savage)    Post Malone  2019      51
# ...                                    ...            ...   ...     ...
# 3701                            STARGAZING   Travis Scott  2019       1
# 1384                               Fabergé            RIN  2019       1
# 3649  Rule The World (feat. Ariana Grande)       2 Chainz  2019       1
# 1425                              Fantasía          Ozuna  2019       1
# 0                                        !   Trippie Redd  2019       1
#
# [1056 rows x 4 columns]                          track_name          artist  year  counts
# 3304                        Perfect      Ed Sheeran  2018      52
# 1781      Havana (feat. Young Thug)  Camila Cabello  2018      52
# 1979                   I Fall Apart     Post Malone  2018      52
# 2001               I Like Me Better            Lauv  2018      52
# 2982                      New Rules        Dua Lipa  2018      52
# ...                             ...             ...   ...     ...
# 1382    FRIENDS (feat. kiLL edward)         J. Cole  2018       1
# 3690        SMASH! - feat. PnB Rock    XXXTENTACION  2018       1
# 1399             Fallin' All In You    Shawn Mendes  2018       1
# 3663                        Runaway        Lil Peep  2018       1
# 1419  Famous (feat. Reginae Carter)       Lil Wayne  2018       1
#
# [1138 rows x 4 columns]

# %%
print(ee)
# Out:
#                                   track_name            artist  year  counts
# 4319                      That's What I Like        Bruno Mars  2017      52
# 5121                              goosebumps      Travis Scott  2017      52
# 3515                                 Redbone  Childish Gambino  2017      52
# 3326                              Photograph        Ed Sheeran  2017      52
# 3154                               One Dance             Drake  2017      52
# ...                                      ...               ...   ...     ...
# 1387                                   Faint       Linkin Park  2017       1
# 1397  Faking It (feat. Kehlani & Lil Yachty)     Calvin Harris  2017       1
# 1416                                  Famous         21 Savage  2017       1
# 1417                                  Famous        Kanye West  2017       1
# 3656        Run Rudolph Run - Single Version       Chuck Berry  2017       1
#
# [889 rows x 4 columns]

# %% [markdown]
# ## moda global

# %%
moda = df[["track_name", "artist"]].value_counts().to_frame().reset_index()
moda.columns = ["track_name", "artist", "counts"]
moda.sort_values("counts", ascending = False)
# Out:
#                                  track_name           artist  counts
# 0                              Shape of You       Ed Sheeran     256
# 1                                  Believer  Imagine Dragons     255
# 2                      Say You Won't Let Go     James Arthur     254
# 3                                   Perfect       Ed Sheeran     249
# 4                                goosebumps     Travis Scott     223
# ...                                     ...              ...     ...
# 3321                                  Hands       Mac Miller       1
# 3320                               Hands On       Kanye West       1
# 3319               Happy Xmas (War Is Over)      Céline Dion       1
# 3318                   Sober II (Melodrama)            Lorde       1
# 4174  M' Manc (con Geolier & Sfera Ebbasta)           Shablo       1
#
# [4175 rows x 3 columns]

# %% [markdown]
# ## moda artistas

# %%
moda_artista = df[["artist"]].value_counts().to_frame().reset_index()
moda_artista.columns = ["artist", "counts"]
moda_artista.sort_values("counts", ascending = False)
# Out:
#                   artist  counts
# 0             Ed Sheeran    1486
# 1            Post Malone    1389
# 2          Billie Eilish    1078
# 3                  Drake    1075
# 4           XXXTENTACION     973
# ..                   ...     ...
# 879   AK AUSSERKONTROLLE       1
# 878          Iggy Azalea       1
# 877                Irama       1
# 876                Ghali       1
# 955  My Chemical Romance       1
#
# [956 rows x 2 columns]

# %% [markdown]
# # Canción más escuchada por año

# %%
graficar(df, "Sunflower - Spider-Man: Into the Spider-Verse" , "position")

# %%
name = "Sunflower - Spider-Man: Into the Spider-Verse"
sng = df[df.track_name == name]
sng.index = sng.start
ax = sng["streams"].plot(title = name, grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
df[df["instrumentalness"] > 0.5].groupby("track_name").mean()
# Out:
#                               position         year       streams  \
# track_name
# Alien Blues                 161.000000  2021.000000  6.128854e+06
# Astronomia                  141.750000  2020.000000  5.304811e+06
# Beautiful Trip              183.000000  2020.000000  6.108393e+06
# Butter (Instrumental)        95.000000  2021.000000  7.450126e+06
# Chromatica I                 93.000000  2020.000000  6.630385e+06
# Chromatica II                87.000000  2020.000000  7.136521e+06
# Freaks                       91.628571  2021.000000  7.817789e+06
# Hypnotised                  157.000000  2017.000000  3.658010e+06
# In My Room                  182.000000  2019.000000  4.615538e+06
# JACKBOYS                    143.000000  2020.000000  5.363493e+06
# Jonestown (Interlude)        93.500000  2018.000000  8.098439e+06
# Levels - Radio Edit          98.750000  2018.000000  8.511386e+06
# Lips                        198.000000  2017.000000  2.705104e+06
# Many Men                     68.000000  2020.000000  8.675173e+06
# NDA                          49.666667  2021.000000  1.180542e+07
# No Child Left Behind         76.000000  2021.000000  1.037709e+07
# Not My Responsibility       120.000000  2021.000000  6.570289e+06
# OverHeated                  106.000000  2021.000000  7.162393e+06
# Oxytocin                     70.000000  2021.000000  9.578804e+06
# Rap Saved Me (feat. Quavo)  161.000000  2017.000000  4.025733e+06
# Risiko                      127.000000  2018.000000  4.811649e+06
# Self                        119.500000  2019.000000  6.181950e+06
# Sunset Lover                 93.588235  2017.000000  5.588118e+06
# everything i wanted          90.355263  2020.144737  1.100943e+07
# goodbye                      99.000000  2019.000000  7.765410e+06
# masquerade                  178.000000  2021.000000  5.438514e+06
# whoa (mind in awe)           77.300000  2018.700000  9.293800e+06
#
#                             danceability  energy  loudness  speechiness  \
# track_name
# Alien Blues                        0.464   0.682    -8.541       0.0330
# Astronomia                         0.653   0.945    -2.634       0.0960
# Beautiful Trip                     0.331   0.513   -15.392       0.6320
# Butter (Instrumental)              0.429   0.387    -7.486       0.0753
# Chromatica I                       0.231   0.457   -10.773       0.0318
# Chromatica II                      0.184   0.297   -14.534       0.0359
# Freaks                             0.346   0.944    -9.874       0.0485
# Hypnotised                         0.513   0.683    -6.185       0.0320
# In My Room                         0.861   0.647    -7.425       0.0675
# JACKBOYS                           0.413   0.130   -25.166       0.0336
# Jonestown (Interlude)              0.380   0.454   -10.271       0.0362
# Levels - Radio Edit                0.579   0.887    -5.961       0.0334
# Lips                               0.523   0.591    -8.772       0.0543
# Many Men                           0.635   0.793    -4.333       0.0322
# NDA                                0.765   0.373    -9.915       0.0713
# No Child Left Behind               0.161   0.327    -8.059       0.0341
# Not My Responsibility              0.468   0.130   -18.031       0.0571
# OverHeated                         0.777   0.522   -12.496       0.0535
# Oxytocin                           0.757   0.598    -7.777       0.0580
# Rap Saved Me (feat. Quavo)         0.845   0.399    -7.509       0.3120
# Risiko                             0.773   0.740    -7.210       0.0895
# Self                               0.618   0.693    -7.889       0.3330
# Sunset Lover                       0.783   0.467    -9.474       0.0503
# everything i wanted                0.704   0.225   -14.454       0.0994
# goodbye                            0.153   0.138   -21.877       0.0503
# masquerade                         0.608   0.792    -5.721       0.0355
# whoa (mind in awe)                 0.735   0.525    -2.939       0.0441
#
#                             acousticness  instrumentalness  liveness  valence  \
# track_name
# Alien Blues                     0.076800             0.832    0.0856   0.4550
# Astronomia                      0.005610             0.915    0.4390   0.3250
# Beautiful Trip                  0.972000             0.953    0.8820   0.4200
# Butter (Instrumental)           0.000178             0.802    0.1420   0.4100
# Chromatica I                    0.012600             0.875    0.3270   0.0588
# Chromatica II                   0.473000             0.893    0.5270   0.1130
# Freaks                          0.000042             0.565    0.0546   0.4030
# Hypnotised                      0.339000             0.739    0.0871   0.1530
# In My Room                      0.594000             0.661    0.1140   0.6700
# JACKBOYS                        0.900000             0.820    0.1110   0.0676
# Jonestown (Interlude)           0.755000             0.623    0.2630   0.2880
# Levels - Radio Edit             0.048400             0.828    0.2940   0.4720
# Lips                            0.494000             0.511    0.0788   0.1950
# Many Men                        0.000647             0.747    0.1130   0.2810
# NDA                             0.329000             0.541    0.1120   0.5900
# No Child Left Behind            0.006320             0.792    0.1380   0.0815
# Not My Responsibility           0.454000             0.927    0.0819   0.0362
# OverHeated                      0.527000             0.838    0.0968   0.1820
# Oxytocin                        0.090400             0.551    0.1500   0.1800
# Rap Saved Me (feat. Quavo)      0.005250             0.741    0.1020   0.1480
# Risiko                          0.155000             0.514    0.1590   0.2260
# Self                            0.440000             0.759    0.1010   0.4390
# Sunset Lover                    0.729000             0.809    0.1090   0.2360
# everything i wanted             0.902000             0.657    0.1060   0.2430
# goodbye                         0.837000             0.550    0.2540   0.0503
# masquerade                      0.000674             0.653    0.2520   0.6110
# whoa (mind in awe)              0.653000             0.918    0.1010   0.3690
#
#                               tempo  duration_ms  duration_s  duration_m
# track_name
# Alien Blues                  80.062     156057.0     156.057    2.600950
# Astronomia                  126.093     198095.0     198.095    3.301583
# Beautiful Trip              133.971      37013.0      37.013    0.616883
# Butter (Instrumental)       109.893     162147.0     162.147    2.702450
# Chromatica I                 65.827      60400.0      60.400    1.006667
# Chromatica II                75.824      41867.0      41.867    0.697783
# Freaks                      179.630     147036.0     147.036    2.450600
# Hypnotised                  120.056     355172.0     355.172    5.919533
# In My Room                  158.037     133680.0     133.680    2.228000
# JACKBOYS                    123.342      46837.0      46.837    0.780617
# Jonestown (Interlude)        77.592     112013.0     112.013    1.866883
# Levels - Radio Edit         126.041     201920.0     201.920    3.365333
# Lips                        173.940     200627.0     200.627    3.343783
# Many Men                     77.594     201856.0     201.856    3.364267
# NDA                          85.015     195777.0     195.777    3.262950
# No Child Left Behind        135.382     178061.0     178.061    2.967683
# Not My Responsibility       115.039     227680.0     227.680    3.794667
# OverHeated                  115.008     214059.0     214.059    3.567650
# Oxytocin                    124.951     210233.0     210.233    3.503883
# Rap Saved Me (feat. Quavo)  143.049     257600.0     257.600    4.293333
# Risiko                      117.023     223381.0     223.381    3.723017
# Self                        143.980     229960.0     229.960    3.832667
# Sunset Lover                 90.838     237793.0     237.793    3.963217
# everything i wanted         120.006     245426.0     245.426    4.090433
# goodbye                      74.318     119410.0     119.410    1.990167
# masquerade                  161.104     144536.0     144.536    2.408933
# whoa (mind in awe)          160.147     157777.0     157.777    2.629617

# %%
graficar(df, "Shape of You" , "position")

# %%
graficar
# Out:
# <function cosas_spotipy.graficar(df_out, name, type='streams')>

# %%
df
# Out:
#        position  year       start         end  \
# 0             1  2017  2016-12-30  2017-01-06
# 1             2  2017  2016-12-30  2017-01-06
# 2             3  2017  2016-12-30  2017-01-06
# 3             4  2017  2016-12-30  2017-01-06
# 4             5  2017  2016-12-30  2017-01-06
# ...         ...   ...         ...         ...
# 51988       196  2021  2021-12-24  2021-12-31
# 51989       197  2021  2021-12-24  2021-12-31
# 51990       198  2021  2021-12-24  2021-12-31
# 51991       199  2021  2021-12-24  2021-12-31
# 51992       200  2021  2021-12-24  2021-12-31
#
#                                               track_name            artist  \
# 0                                                Starboy        The Weeknd
# 1                                                 Closer  The Chainsmokers
# 2                Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 3                                        Let Me Love You          DJ Snake
# 4      I Don’t Wanna Live Forever (Fifty Shades Darke...              ZAYN
# ...                                                  ...               ...
# 51988                                            Circles       Post Malone
# 51989                                MIDDLE OF THE NIGHT        Elley Duhé
# 51990                                         The Nights            Avicii
# 51991                               Merry Xmas Everybody             Slade
# 51992              Mistletoe And Holly - Remastered 1999     Frank Sinatra
#
#         streams  danceability  energy  loudness  speechiness  acousticness  \
# 0      25734078         0.681   0.594    -7.028       0.2820        0.1650
# 1      23519705         0.748   0.524    -5.599       0.0338        0.4140
# 2      21216399         0.720   0.763    -4.068       0.0523        0.4060
# 3      19852704         0.476   0.718    -5.309       0.0576        0.0784
# 4      18316326         0.735   0.451    -8.374       0.0585        0.0631
# ...         ...           ...     ...       ...          ...           ...
# 51988   5665497         0.704   0.758    -3.537       0.0402        0.2330
# 51989   5658747         0.410   0.611    -8.271       0.0467        0.0228
# 51990   5631220         0.527   0.835    -5.298       0.0433        0.0166
# 51991   5611874         0.405   0.752    -5.452       0.0394        0.1380
# 51992   5595377         0.607   0.103   -14.405       0.0404        0.8040
#
#        instrumentalness  liveness  valence    tempo  duration_ms  duration_s  \
# 0              0.000003    0.1340   0.5350  186.054       230453     230.453
# 1              0.000000    0.1110   0.6610   95.010       244960     244.960
# 2              0.000000    0.1800   0.7420  101.965       251088     251.088
# 3              0.000010    0.1220   0.1420  199.864       205947     205.947
# 4              0.000013    0.3250   0.0862  117.973       245200     245.200
# ...                 ...       ...      ...      ...          ...         ...
# 51988          0.001440    0.0924   0.5340  120.003       214907     214.907
# 51989          0.000000    0.1160   0.0899  185.727       184448     184.448
# 51990          0.000000    0.2490   0.6540  125.983       176658     176.658
# 51991          0.000000    0.1730   0.4330  130.228       223684     223.684
# 51992          0.000000    0.0760   0.3410  110.378       136427     136.427
#
#        duration_m
# 0        3.840883
# 1        4.082667
# 2        4.184800
# 3        3.432450
# 4        4.086667
# ...           ...
# 51988    3.581783
# 51989    3.074133
# 51990    2.944300
# 51991    3.728067
# 51992    2.273783
#
# [51993 rows x 19 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
a = df[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
    'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']]
aa =  ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
          'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']

cormat = a.corr()
f, ax = plt.subplots(figsize=(12,9))
sns.heatmap(cormat, vmax= .85, square=True)

k = 10
cols = cormat.nlargest(k,aa[2])[aa[2]].index
cols

cm = np.corrcoef(a[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=False, annot=True, square=True, fmt=".2f", annot_kws={"size": 10}, yticklabels=cols.values, xticklabels=cols.values)

# %%
tendencia_semanal = df.groupby("start").agg(
    danceability = ("danceability","mean"),
    energy = ("energy","mean"),
    loudness = ("loudness","mean"),
    speechiness = ("speechiness","mean"),
    acousticness = ("acousticness","mean"),
    instrumentalness = ("instrumentalness","mean"),
    liveness = ("liveness","mean"),
    valence = ("valence","mean"),
    tempo = ("tempo","mean"),
    duration_ms = ("duration_ms","mean")
    )

# %%
fig = plt.figure()
ax = tendencia_semanal.danceability.plot(title = "tendencia", grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
fig = plt.figure()
ax = tendencia_semanal.energy.plot(title = "tendencia", grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
fig = plt.figure()
ax = tendencia_semanal.loudness.plot(title = "tendencia", grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
fig = plt.figure()
ax = tendencia_semanal.speechiness.plot(title = "tendencia", grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
fig = plt.figure()
ax = tendencia_semanal.acousticness.plot(title = "tendencia", grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
fig = plt.figure()
ax = tendencia_semanal.instrumentalness.plot(title = "tendencia", grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
fig = plt.figure()
ax = tendencia_semanal.liveness.plot(title = "tendencia", grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
fig = plt.figure()
ax = tendencia_semanal.valence.plot(title = "tendencia", grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
fig = plt.figure()
ax = tendencia_semanal.tempo.plot(title = "tendencia", grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
fig = plt.figure()
ax = tendencia_semanal.duration_ms.plot(title = "tendencia", grid = True, figsize = (20,6))
ax.set_xlabel("date")
ax.set_ylabel("streams")
# Out:
# Text(0, 0.5, 'streams')

# %%
# Prueba de Box Pierce
